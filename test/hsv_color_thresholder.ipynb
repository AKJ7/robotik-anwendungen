# %%
import cv2 as cv
import numpy as np


def nothing(x):
    pass


cv.namedWindow('image', cv.WINDOW_FREERATIO)
cv.createTrackbar('HMin', 'image', 0, 179, nothing)
cv.createTrackbar('SMin', 'image', 0, 255, nothing)
cv.createTrackbar('VMin', 'image', 0, 255, nothing)
cv.createTrackbar('HMax', 'image', 0, 179, nothing)
cv.createTrackbar('SMax', 'image', 0, 255, nothing)
cv.createTrackbar('VMax', 'image', 0, 255, nothing)
cv.setTrackbarPos('HMax', 'image', 179)
cv.setTrackbarPos('SMax', 'image', 255)
cv.setTrackbarPos('VMax', 'image', 255)
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0
img = cv.imread('01_23_2022_16_07_40.jpg')
output = img
waitTime = 33
while True:
    hMin = cv.getTrackbarPos('HMin', 'image')
    sMin = cv.getTrackbarPos('SMin', 'image')
    vMin = cv.getTrackbarPos('VMin', 'image')

    hMax = cv.getTrackbarPos('HMax', 'image')
    sMax = cv.getTrackbarPos('SMax', 'image')
    vMax = cv.getTrackbarPos('VMax', 'image')

    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    mask = cv.inRange(hsv, lower, upper)
    output = cv.bitwise_and(img,img, mask= mask)

    if (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax):
        print(f'(hMin = {hMin} , sMin = {sMin}, vMin = {vMin}), (hMax = {hMax} , sMax = {sMax}, vMax = {vMax})')
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    cv.imshow('image',output)

    if cv.waitKey(waitTime) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 32 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 16 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 42, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 48, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 57, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 60, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 71, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 89, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 87, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 82, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 69, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 63, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 39, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 1), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 11), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 22), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 24), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 29), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 33), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 37), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 44), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 48), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 51), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 54), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 56), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 58), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 59), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 60), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 61), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 63), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 65), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 67), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 69), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 70), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 71), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 72), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 73), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 74), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 75), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 77), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 84), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 86), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 90), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 91), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 92), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 95), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 122), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin =